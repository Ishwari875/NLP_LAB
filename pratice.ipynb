# %%
pip install spacy
# Out:
# Collecting spacy
#   Downloading spacy-3.7.5-cp310-cp310-win_amd64.whl (12.1 MB)
#      -------------------------------------- 12.1/12.1 MB 177.8 kB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Collecting thinc<8.3.0,>=8.2.2
#   Downloading thinc-8.2.5-cp310-cp310-win_amd64.whl (1.5 MB)
#      ---------------------------------------- 1.5/1.5 MB 172.8 kB/s eta 0:00:00
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: setuptools in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (65.6.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: jinja2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Collecting murmurhash<1.1.0,>=0.28.0
#   Downloading murmurhash-1.0.10-cp310-cp310-win_amd64.whl (25 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0
#   Downloading spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Collecting catalogue<2.1.0,>=2.0.6
#   Downloading catalogue-2.0.10-py3-none-any.whl (17 kB)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (1.23.5)
# Collecting spacy-legacy<3.1.0,>=3.0.11
#   Downloading spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Collecting weasel<0.5.0,>=0.1.0
#   Downloading weasel-0.4.1-py3-none-any.whl (50 kB)
#      -------------------------------------- 50.3/50.3 kB 111.2 kB/s eta 0:00:00
# Collecting cymem<2.1.0,>=2.0.2
#   Downloading cymem-2.0.8-cp310-cp310-win_amd64.whl (39 kB)
# Collecting typer<1.0.0,>=0.3.0
#   Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#      -------------------------------------- 47.2/47.2 kB 107.5 kB/s eta 0:00:00
# Collecting preshed<3.1.0,>=3.0.2
#   Downloading preshed-3.0.9-cp310-cp310-win_amd64.whl (122 kB)
#      ------------------------------------ 122.2/122.2 kB 102.4 kB/s eta 0:00:00
# Collecting srsly<3.0.0,>=2.4.3
#   Downloading srsly-2.4.8-cp310-cp310-win_amd64.whl (481 kB)
#      ------------------------------------- 481.9/481.9 kB 98.6 kB/s eta 0:00:00
# Collecting wasabi<1.2.0,>=0.9.1
#   Downloading wasabi-1.1.3-py3-none-any.whl (27 kB)
# Collecting langcodes<4.0.0,>=3.2.0
#   Downloading langcodes-3.4.0-py3-none-any.whl (182 kB)
#      ------------------------------------ 182.0/182.0 kB 199.8 kB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (22.0)
# Collecting language-data>=1.2
#   Downloading language_data-1.2.0-py3-none-any.whl (5.4 MB)
#      ---------------------------------------- 5.4/5.4 MB 165.5 kB/s eta 0:00:00
# Requirement already satisfied: pydantic-core==2.14.5 in c:\users\ishwari\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.5)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ishwari\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ishwari\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Collecting blis<0.8.0,>=0.7.8
#   Downloading blis-0.7.11-cp310-cp310-win_amd64.whl (6.6 MB)
#      ---------------------------------------- 6.6/6.6 MB 46.3 kB/s eta 0:00:00
# Collecting confection<1.0.0,>=0.0.1
#   Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Requirement already satisfied: colorama in c:\users\ishwari\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Collecting rich>=10.11.0
#   Downloading rich-13.7.1-py3-none-any.whl (240 kB)
#      ------------------------------------ 240.7/240.7 kB 100.3 kB/s eta 0:00:00
# Collecting shellingham>=1.3.0
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: click>=8.0.0 in c:\users\ishwari\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\ishwari\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Collecting cloudpathlib<1.0.0,>=0.7.0
#   Downloading cloudpathlib-0.18.1-py3-none-any.whl (47 kB)
#      -------------------------------------- 47.3/47.3 kB 131.5 kB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ishwari\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Collecting marisa-trie>=0.7.7
#   Downloading marisa_trie-1.2.0-cp310-cp310-win_amd64.whl (152 kB)
#      ------------------------------------ 152.4/152.4 kB 151.7 kB/s eta 0:00:00
# Collecting pygments<3.0.0,>=2.13.0
#   Downloading pygments-2.18.0-py3-none-any.whl (1.2 MB)
#      ---------------------------------------- 1.2/1.2 MB 77.7 kB/s eta 0:00:00
# Collecting markdown-it-py>=2.2.0
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
#      --------------------------------------- 87.5/87.5 kB 82.5 kB/s eta 0:00:00
# Collecting mdurl~=0.1
#   Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, shellingham, pygments, murmurhash, mdurl, marisa-trie, cloudpathlib, catalogue, blis, srsly, preshed, markdown-it-py, language-data, rich, langcodes, confection, typer, thinc, weasel, spacy
#   Attempting uninstall: pygments
#     Found existing installation: Pygments 2.11.2
#     Uninstalling Pygments-2.11.2:
#       Successfully uninstalled Pygments-2.11.2
# Successfully installed blis-0.7.11 catalogue-2.0.10 cloudpathlib-0.18.1 confection-0.1.5 cymem-2.0.8 langcodes-3.4.0 language-data-1.2.0 marisa-trie-1.2.0 markdown-it-py-3.0.0 mdurl-0.1.2 murmurhash-1.0.10 preshed-3.0.9 pygments-2.18.0 rich-13.7.1 shellingham-1.5.4 spacy-3.7.5 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.2.5 typer-0.12.3 wasabi-1.1.3 weasel-0.4.1
# Requirement already satisfied: spacy in c:\users\ishwari\anaconda3\lib\site-packages (3.7.5)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (8.2.5)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (1.23.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (22.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (0.12.3)
# Requirement already satisfied: jinja2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: setuptools in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (65.6.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\ishwari\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: pydantic-core==2.14.5 in c:\users\ishwari\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ishwari\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ishwari\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\ishwari\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ishwari\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: colorama in c:\users\ishwari\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ishwari\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\ishwari\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ishwari\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\ishwari\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\ishwari\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ishwari\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\ishwari\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ishwari\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ishwari\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ishwari\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install spacy
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\users\ishwari\anaconda3\lib\site-packages (3.7.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (2.28.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (2.5.2)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: setuptools in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (65.6.3)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (8.2.5)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (22.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: jinja2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (0.12.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (4.64.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: language-data>=1.2 in c:\users\ishwari\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ishwari\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.8.0)
# Requirement already satisfied: pydantic-core==2.14.5 in c:\users\ishwari\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.14.5)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ishwari\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.6.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\ishwari\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ishwari\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: colorama in c:\users\ishwari\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ishwari\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.7.1)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ishwari\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: click>=8.0.0 in c:\users\ishwari\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.0.4)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\ishwari\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (5.2.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\ishwari\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.18.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ishwari\anaconda3\lib\site-packages (from jinja2->spacy) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\ishwari\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ishwari\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ishwari\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ishwari\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      -------------------------------------- 12.8/12.8 MB 274.2 kB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\ishwari\anaconda3\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.28.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.23.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: jinja2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.3)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.5.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.64.1)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: setuptools in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (65.6.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.12.3)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\ishwari\anaconda3\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (22.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\ishwari\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\ishwari\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\ishwari\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.8.0)
# Requirement already satisfied: pydantic-core==2.14.5 in c:\users\ishwari\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.14.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ishwari\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2022.12.7)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\ishwari\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.5)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\ishwari\anaconda3\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: colorama in c:\users\ishwari\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\ishwari\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\ishwari\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\ishwari\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (13.7.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\ishwari\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.18.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\ishwari\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ishwari\anaconda3\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\ishwari\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ishwari\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ishwari\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ishwari\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.2)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.7.1
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

for token in doc:
    print(token.text, token.lemma_, token.pos_, token.tag_, token.dep_,
            token.shape_, token.is_alpha, token.is_stop)
# Out:
# Apple Apple PROPN NNP nsubj Xxxxx True False
# is be AUX VBZ aux xx True True
# looking look VERB VBG ROOT xxxx True False
# at at ADP IN prep xx True True
# buying buy VERB VBG pcomp xxxx True False
# U.K. U.K. PROPN NNP dobj X.X. False False
# startup startup NOUN NN dep xxxx True False
# for for ADP IN prep xxx True True
# $ $ SYM $ quantmod $ False False
# 1 1 NUM CD compound d False False
# billion billion NUM CD pobj xxxx True False

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
print("Pipeline:", nlp.pipe_names)
doc = nlp("I was reading the paper.")
token = doc[0]  # 'I'
print(token.morph)  # 'Case=Nom|Number=Sing|Person=1|PronType=Prs'
print(token.morph.get("PronType"))  # ['Prs']
# Out:
# Pipeline: ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']
# Case=Nom|Number=Sing|Person=1|PronType=Prs
# ['Prs']

# %%
import spacy

# English pipelines include a rule-based lemmatizer
nlp = spacy.load("en_core_web_sm")
lemmatizer = nlp.get_pipe("lemmatizer")
print(lemmatizer.mode)  # 'rule'

doc = nlp("I was reading the paper.")
print([token.lemma_ for token in doc])
# ['I', 'be', 'read', 'the', 'paper', '.']
# Out:
# rule
# ['I', 'be', 'read', 'the', 'paper', '.']

# %%
import spacy

nlp = spacy.load("en_core_web_sm")
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")
for token in doc:
    print(token.text)
# Out:
# Apple
# is
# looking
# at
# buying
# U.K.
# startup
# for
# $
# 1
# billion
